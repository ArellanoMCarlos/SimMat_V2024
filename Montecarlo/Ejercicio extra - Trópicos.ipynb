# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Los siguientes datos son extraídas de la estación climática Copernicus C3S. Son temperaturas interpoladas usando modelos físicos de los trópicos desde 1940 a la fecha:

# %%
data_link='https://climatereanalyzer.org/clim/t2_daily/json/era5_tropics_t2_day.json'
# Más datos en:
# https://climatereanalyzer.org/clim/t2_daily/?dm_id=world
data=pd.read_json(data_link)
last=366-pd.DataFrame(data.data[84]).isna().sum()[0]
fecha=pd.concat([pd.date_range('1940-01-01','2023-12-31').to_series(),pd.date_range('2024-01-01',periods=last).to_series()])
datos=np.concatenate([i for i in data.iloc[:-3,-1]])
df_temps=pd.DataFrame(datos).dropna()
df_temps.index=fecha
df_temps.columns=['data']
df_temps
# Out:
#               data
# 1940-01-01  24.266
# 1940-01-02  24.327
# 1940-01-03  24.297
# 1940-01-04  24.308
# 1940-01-05   24.28
# ...            ...
# 2024-06-14  26.182
# 2024-06-15  26.117
# 2024-06-16  26.058
# 2024-06-17  26.049
# 2024-06-18  26.069
#
# [30851 rows x 1 columns]

# %% [markdown]
# Analicemos el conjunto de temperaturas para averiguar la probabilidad de que la temperatura baje un 1\% en un mes

# %%
# Calcular la variación porcentual de temperaturas (R)

# Nos aseguramos de que 'R' tenga media constante a los largo de todos los años (o sea, graficamos 'R')

# Nos aseguramos de que 'R' tenga distribución Normal.
# Si no, usamos otra forma de calcular 'R' o generamos los datos con otra distribución

# Generamos 10000 números aleatorios con la media y std de 'R' para un mes
# (o sea, una matriz de 30x10000 con sus respectivas fechas)

# Proyectamos las temperaturas de la matriz simulada

# Calculamos la variable de Bernoulli (B)
# (cuántos escenarios están por debajo del 99% de la última temperatura conocida)

# Calculamos la probabilidad a partir de 'B'
