# %%
import sympy as sym

# %%
sym.var('b')
l=(10-b)/2    # 10=b+2*l
V=1/3*sym.pi*(b/2)**2*sym.sqrt(l**2-(b/2)**2)
h=sym.sqrt(l**2-(b/2)**2)
V
# Out:
# 0.0833333333333333*pi*b**2*sqrt(-b**2/4 + (5 - b/2)**2)

# %%
dV=sym.diff(V,b)
c=sym.solve(dV)
c
# Out:
# [0.0, 4.00000000000000]

# %%
float(V.subs(b,c[1]))
# Out:
# 9.366419641387635

# %%
h.subs(b,c[1])
# Out:
# 2.23606797749979

# %%
l.subs(b,c[1])
# Out:
# 3.00000000000000

# %%
sym.var('x',real=True)
def A(x):
  return x*(6-2*x)
dA=A(x).diff(x)
c=sym.solve(dA)
c
# Out:
# [3/2]

# %%
def S(x):
  y=36/x**2
  return 4*x**2+6*x*y
dS=S(x).diff(x)
c=sym.solve(dS)
c
# Out:
# [3]

# %%
def L(x):
  h1=(5**2+x**2)**(1/2)
  h2=(4**2+(2.2-x)**2)**(1/2)
  return h1+h2
dL=L(x).diff(x)
c=sym.solve(dL)
c
# Out:
# [1.22222222222222]

# %%
# Punto 'P'
0.8+c[0]
# Out:
# 2.02222222222222

# %%
L(c[0])
# Out:
# 9.26498785752037

# %%
(9**2+2.2**2)**(1/2) # La distancia más corta entre dos puntos en un plano
# Out:
# 9.264987857520376
