# %% [markdown]
# # Optimización de funciones escalares diferenciables con `SymPy`
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Extrema_example_es.svg/1200px-Extrema_example_es.svg.png" width="300px" height="190px" />
#
# - Mediante optimización se obtienen soluciones elegantes tanto en teoría como en ciertas aplicaciones.
# - La teoría de optimización usa elementos comenzando con cálculo elemental y álgebra lineal básica, y luego se extiende con análisis funcional y convexo.
# - Las aplicaciones en optimización involucran ciencia, ingeniería, economía, finanzas e industria.
# - El amplio y creciente uso de la optimización lo hace escencial para estudiantes y profesionales de cualquier rama de la ciencia y la tecnología.
#
# **Referencia:**
# - http://www.math.uwaterloo.ca/~hwolkowi//henry/reports/talks.d/t06talks.d/06msribirs.d/optimportance.shtml

# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e7/OpenStreetMap_routing_service.png/300px-OpenStreetMap_routing_service.png" width="200px" height="150px" />
#
# ### Algunas aplicaciones son:
#
# 1. **Ingeniería:**
#  - Encontrar la composición de equilibrio de una mezcla de diferentes átomos.
#  - Planeación de ruta para un robot (o vehículo aéreo no tripulado).
#  - Planeación de la mano de obra óptima en una construcción o planta de producción.
#  - Análisis conformacional - Isomería conformacional en modelado molecular
#  - Desempeño en fermentación de productos.
#  - Estimación de parámetros en bioquímica e ingeniería metabólica.
#
#
# 2. **Distribución óptima de recursos:**
#  - Distribución de rutas de vuelo.
#  - Encontrar una dieta óptima.
#  - Planeación de ruta óptima.
#
#
# 3. **Optimización financiera:**
#  - Administración de riesgos.
#  - Portafolios de inversión.
#  - Problema de maximización de la utilidad.
#  - la calibración de modelos de precios de opciones para datos de mercado
#  - la optimización de la función de utilidad de un agente

# %% [markdown]
# ### <p style="color:green;">En esta clase veremos aspectos básicos de optimización. Específicamente, veremos cómo obtener máximos y mínimos de una función escalar de una variable (como en cálculo diferencial).</p>
#
# <img style="float: center" src="https://matematicasies.com/local/cache-vignettes/L337xH278/extremos-77d0a.png" width="500px" height="300px" />

# %% [markdown]
# # Antes de empezar: Poquito de Python
# * Es un lenguaje interpretado (usa scripts).
# * Es un lenguaje dinámico. O sea, no necesitamos definir las variables.

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
a=1.0

# %%
type(a)
# Out:
# float

# %% [markdown]
# * Es un lenguaje orientado a objetos

# %%
a.hex()
# Out:
# '0x1.0000000000000p+0'

# %%
a=1+1j

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 1.0

# %%
a.imag
# Out:
# 1.0

# %% [markdown]
# ## Algunos tipos de variables
# * Numéricas: enteras, flotantes, complejas
# * Booleanas
# * De texto

# %%
# Booleana
a_bool=True

# %%
b_bool=False

# %%
# De texto
a_texto="texto"
b_texto='otro texto'
c_texto='''texto con formato
podemos dar saltos de línea'''
c_texto    # Esto es para visualizar la variable
# Out:
# 'texto con formato\npodemos dar saltos de línea'

# %%
print(c_texto)
# Out:
# texto con formato
# podemos dar saltos de línea

# %%
# Concatenación (suma)
a_texto+b_texto
# Out:
# 'textootro texto'

# %%
# Multiplicación
a_texto*3
# Out:
# 'textotextotexto'

# %%
# Potencias
# a=1+1j
a**3
# Out:
# (-2+2j)

# %% [markdown]
# ```python
# (1+1j)**3=1-3+3j-1j
# ```

# %% [markdown]
# * Arreglos: Mutables (listas, el valor de los diccionarios) e inmutables (tuplas, el identificador de los diccionarios y los textos).

# %%
# Tuplas (no podemos modificar sus elementos)
t=(1,1.0,'hola',(1,2,3))

# %%
t[0]
# Out:
# 1

# %%
t[3]
# Out:
# (1, 2, 3)

# %%
# Esto marca error
# t[0]=0

# %%
L=[1,2,3,'cuarto elemento']
L[0]
# Out:
# 1

# %%
L[0]=0
L
# Out:
# [0, 2, 3, 'cuarto elemento']

# %%
L[-1] # último elemento
# Out:
# 'cuarto elemento'

# %%
L[-2] # penúltimo elemento
# Out:
# 3

# %%
t=(1,2,3,[4,5,6])
t[-1][0]=0

# %%
t
# Out:
# (1, 2, 3, [0, 5, 6])

# %% [markdown]
# ```
# !pip install numpy
# ```

# %% [markdown]
# ___
# # Librerías que usaremos
# <img style="float: center" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Python3-powered_hello-world.svg/1000px-Python3-powered_hello-world.svg.png" width="200px" height="100px" />

# %% [markdown]
# ### `NumPy`
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://numpy.org/images/logo.svg" width="300px" height="100px" />
#
# `NumPy` (Numerical Python) es la librería fundamental para computación científica (numérica) con `Python`. Contiene, entre otras cosas:
# - un objeto tipo arreglo N-dimensional muy poderoso
# - funciones sofisticadas
# - funciones de álgebra lineal, transformada de Fourier y números aleatorios.
#
# Por lo anterior, `NumPy` es de amplio uso entre la comunidad científica e ingenieril (por su manejo de cantidades vectoriales). De la misma manera, se usa para guardar datos. Para nuestros propósitos, se puede usar libremente.
#
# **Referencia:**
# - http://www.numpy.org/

# %% [markdown]
# `NumPy` ya viene incluido en la instalación estándar de Anaconda por defecto. Para comenzar a usarlo, solo debemos de importarlo:

# %%
# Importar librería numpy
import numpy as np

# %%
np.e
# Out:
# 2.718281828459045

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.sin(np.pi/3)
# Out:
# 0.8660254037844386

# %%
arreglo=np.array([1,2,3,4])
arreglo
# Out:
# array([1, 2, 3, 4])

# %%
# Multiplicación por escalar
arreglo*3
# Out:
# array([ 3,  6,  9, 12])

# %%
# Norma del vector
np.linalg.norm(arreglo)
# Out:
# 5.477225575051661

# %%
# Matrices
M=np.array([[0,1,-1],
            [3,4,6],
            [0,1,1]])
M
# Out:
# array([[ 0,  1, -1],
#        [ 3,  4,  6],
#        [ 0,  1,  1]])

# %%
np.linalg.det(M)
# Out:
# -6.0

# %%
np.linalg.inv(M)
# Out:
# array([[ 0.33333333,  0.33333333, -1.66666667],
#        [ 0.5       ,  0.        ,  0.5       ],
#        [-0.5       ,  0.        ,  0.5       ]])

# %% [markdown]
# ### 0.2 `SymPy`
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="http://www.sympy.org/static/images/logo.png" width="200px" height="100px" />
#
# `SymPy` (Symbolic Python) es una librería de `Python` para matemáticas simbólicas. Su objetivo es convertirse en un sistema de álgebra computacional con las mejores características, manteniendo el código lo más simple posible para que sea comprensible.
#
# **Referencia:**
# - http://www.sympy.org/en/index.html

# %% [markdown]
# `SymPy` ya viene incluido en la instalación estándar de Anaconda por defecto. Para comenzar a usarlo, solo debemos de importarlo:

# %%
#Importarmos la librería sympy
import sympy as sym

# %%
# Ayuda de la función
sym.var('x')
# Out:
# x

# %%
sym.sin(x)+1
# Out:
# sin(x) + 1

# %%
sym.pi
# Out:
# pi

# %%
# from sympy import *

# %%
# pi

# %%
# sin(x)+1

# %% [markdown]
# La funcionalidad de imprimir en formato LaTex que nos da `SymPy` mediante el proyecto `mathjax` hace de `SymPy` una herramienta muy atractiva...

# %% [markdown]
# Notar que en `SymPy` y en `NumPy` existen funciones con el mismo nombre, pero reciben tipos de datos diferentes...

# %%
# from numpy import *

# %%
# pi

# %%
# sin(sym.pi)

# %%
sym.sin(sym.pi)
# Out:
# 0

# %%
sym.pi+1
# Out:
# 1 + pi

# %% [markdown]
# Explicar el uso de la sintaxis `from numpy import *` y sus peligros (**no recomendable**).

# %% [markdown]
# ### 0.3 `PyPlot` de `matplotlib`
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://matplotlib.org/_static/logo2.svg" width="300px" height="100px" />
#
# El módulo `PyPlot` de la librería `matplotlib` contiene funciones que nos permite generar una gran cantidad de gráficas rápidamente. Las funciones de este módulo están escritas con el mismo nombre que las funciones para graficar en `Matlab`.
#
# **Referencia:**
# - https://matplotlib.org/api/pyplot_summary.html

# %%
# importar la librería para graficar
import matplotlib.pyplot as plt

# %%
x=np.linspace(-np.pi,np.pi,500)        # Regresa 500 valores entre -pi y pi
y=np.sin(x)
plt.plot(x,y,':r',label='sen(x)')      # 'r'=línea roja, ':'=línea punteada
y_cos=np.cos(x)
plt.plot(x,y_cos,'--k',label='cos(x)') # 'k'=línea negra, '--'=línea discontínua
plt.legend()                           # Esto es para mostrar las etiquetas
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %%
# Líneas en diferentes gráficos
#
# Gráfico 1
plt.plot(x,y)
plt.grid()

# Gráfico 2
plt.figure()
plt.plot(x,y_cos,'C1')
plt.grid()

# %%
plt.plot?

# %% [markdown]
# ## 1. Teorema de Fermat (análisis)
#
# Si una función $f(x)$ alcanza un máximo o mínimo local en $x=c$, y si la derivada $f'(c)$ existe en el punto $c$, entonces $f'(c) = 0$.

# %% [markdown]
# ### Ejemplo
#
# Sabemos que la función $f(x)=(x-2)^2$ tiene un mínimo global en $x=2$, pues
#
# $$f(x)=(x-2)^2\geq0,\qquad\text{y}\qquad f(x)=(x-2)^2=0 \qquad\text{si y solo si}\qquad x=2.$$

# %%
import sympy as sym               # Librería simbólica
import numpy as np                # Librería numérica
import matplotlib.pyplot as plt   # Librería gráfica

# %%
sym.var('x') # Definición de la variable simbólica
f=(x-2)**2   # Criterio de optimización
f            # Mostramos la función
# Out:
# (x - 2)**2

# %%
# Derivada de 'f' con respecto a 'x'
df=f.diff('x')
df
# Out:
# 2*x - 4

# %%
# Encontramos lass raíces de 'df'
c=sym.solve(df,x) # sym.solve(df)
c
# Out:
# [2]

# %%
c[0] # Punto crítico
# Out:
# 2

# %% [markdown]
# Veamos la gráfica...

# %%
# Convertir función simbólica f a una función numérica
#
# f_num=sym.lambdify(x,f,'numpy')
f_num=sym.lambdify(x,f,np)        # (variable_simbólica, función_a_convertir, librería)

# %%
f_num(0)
# Out:
# 4

# %%
x_num=np.array([0,1,2,3,4])
f_num(x_num)
# Out:
# array([4, 1, 0, 1, 4])

# %%
# Definir coordenas x
x_num=np.linspace(0,4,100) # Sobreescribimos 'x_num' con 100 elementos equidistantes entre 0 y 4

# %%
# Graficar:
#
#   Calcular coordenada en y
y_num=f_num(x_num)

#   Mostrar gráfico
plt.plot(x_num,y_num)                 # Gráfica
plt.plot(c[0],f_num(c[0]),'xr',ms=10) # Punto crítico. 'xr'=cruz roja. ms=marksize
plt.grid()                            # Cuadrícula de fondo

# %% [markdown]
# **Resultado:**
#
# Encontramos un mínimo global en la función $f(x)=(x-2)^2$ en $x=2$.
#
# ---

# %% [markdown]
# Ver diferencias entre f y f_num

# %%
# Esto marca error. Poreso convertimos a numérico
# f(0)

# %% [markdown]
# ### **Otra manera de hacer lo anterior**
#
# Revisemos el concepto de función en `Python`

# %%
def f(z):
  return (z-2)**2

# %%
f(x)
# Out:
# (x - 2)**2

# %%
f(0)
# Out:
# 4

# %%
f # Sobreescribimos la variable 'f'. Ahora 'f' es una función

# %%
# Derivamos 'f(x)'
df=f(x).diff(x)
df
# Out:
# 2*x - 4

# %%
# Encontramos la... raíz
c=sym.solve(df)
c
# Out:
# [2]

# %%
# sym.lambdify?

# %%
# Gráfica
x_num=np.linspace(0,4,100)
y_num=f(x_num)
plt.plot(x_num,y_num)
plt.plot(c[0],f(c[0]),'*g',ms=10) # '*g'=estrella verde. Colores: RGB CMYK
plt.grid()

# %%
sym.var('x')
f=(x-2)**2
f
# Out:
# (x - 2)**2

# %%
f.subs(x,0)
# Out:
# 4

# %%
c[0],f.subs(x,c[0])
# Out:
# (2, 0)

# %% [markdown]
# **El converso del teorema anterior no es cierto.**
#
# ### Actividad
# Considere $g(x)=(x-2)^3$.
# - Usando `sympy`, muestre que $g'(2)=0$.
# - Sin embargo, descartar que $x=2$ es un extremo de $g(x)$ viendo su **gráfica**.

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
sym.var('x')
def g(x):
  return (x-2)**3
dg=g(x).diff(x)
c=sym.solve(dg)
c
# Out:
# [2]

# %%
x_num=np.linspace(0,4,100)
y_num=g(x_num)

plt.plot(x_num,y_num,c[0],g(c[0]),'*',ms=10)
plt.grid()

# %% [markdown]
# **Resultado:**
#
# Encontramos un punto de inflexión en $x=2$ en la función $g(x)=(x-2)^3$.
#
# ---

# %% [markdown]
# ## 2. Criterio de la segunda derivada
#
# Sea $f(x)$ una función tal que $f’(c)=0$ y cuya segunda derivada existe en un intervalo abierto que contiene a $c$.
# - Si $f’’(c)>0$, entonces $f(c)$ es un mínimo relativo.
# - Si $f’’(c)<0$, entonces $f(c)$ es un máximo relativo.
# - Si $f’’(c)=0$, entonces el criterio no decide.

# %% [markdown]
# ### Ejemplo
#
# Mostrar, usando `sympy`, que la función $f(x)=(x-2)^2$ tiene un mínimo relativo en $x=2$.
#
# Ya vimos que $f'(2)=0$. Notemos que:

# %%
def f(x):
  return (x-2)**2
df=f(x).diff(x)
c=sym.solve(df)
c
# Out:
# [2]

# %%
# Derivamos por segunda vez
ddf=df.diff(x) # ddf=f(x).diff(x,2)  =  ddf=f(x).diff(x,x)
ddf
# Out:
# 2

# %% [markdown]
# Por tanto, por el criterio de la segunda derivada, $f(2)=0$ es un mínimo relativo (en efecto, el mínimo global).

# %% [markdown]
# ### Ejemplo
# ¿Qué pasa con $g(x)=(x-2)^3$ al intentar utilizar el criterio de la segunda derivada? (usar `sympy`).

# %%
g(x)
# Out:
# (x - 2)**3

# %%
dg=g(x).diff(x)
ddg=g(x).diff(x,2)
c=sym.solve(dg)
c
# Out:
# [2]

# %%
# sym.diff?

# %%
ddg
# Out:
# 6*(x - 2)

# %%
# Sustituímos la segunda derivada en x=c[0]
ddg.subs(x,c[0]) # x=c[0]=2
# Out:
# 0

# %% [markdown]
# Como $g''(2)=0$ entonces el criterio de la segunda derivada no concluye.

# %% [markdown]
# ### Ejemplo improvisado
#
# > `Esc`, `A`  $\rightarrow$  Crea una celda de código arriba de la celda actual.
#
# Usando el criterio de la segunda derivada, encuentre los extremos de la función
# $$
# f(x)=x(x^2-1).
# $$

# %%
# importamos las librerías
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
# Definimos la variable simbólica y la función
sym.var('x')
def f(x):
  return x*(x**2-1)

# %%
# Derivamos
df=f(x).diff(x)

# Resolvemos
c=sym.solve(df)
c
# Out:
# [-sqrt(3)/3, sqrt(3)/3]

# %%
# Criterio de la segunda derivada
#
ddf=df.diff(x)   # Derivamos la primer derivada

# Primer punto:
ddf.subs(x,c[0]) # Evaluamos el primer punto crítico en 'ddf'
# Out:
# -2*sqrt(3)

# %%
# Secondo
ddf.subs(x,c[1]) # Evaluamos el segundo punto crítico en 'ddf'
# Out:
# 2*sqrt(3)

# %% [markdown]
# **Resultado:**
#
# Encontramos un máximo para $x=-\frac{\sqrt{3}}{3}$ en $f(x)=x(x^2-1)$ y un mínimo local en $x=\frac{\sqrt{3}}{3}$.
#
# ---

# %% [markdown]
# ### Actividad
#
# ¿Qué pasa con $h(x)=(x-2)^4$ al intentar utilizar el criterio de la segunda derivada?.

# %%
def h(x):
  return (x-2)**4
dh=h(x).diff(x)
c=sym.solve(dh)
c               # Punto crítico
# Out:
# [2]

# %%
ddh=dh.diff(x)
ddh.subs(x,c[0])
# Out:
# 0

# %% [markdown]
# Como la segunda derivada evaluada en el punto crítico es cero, usamos la gráfica para definir el extremo.

# %%
x_num=np.linspace(0,4,100)
y_num=h(x_num)

plt.plot(x_num,y_num)
plt.plot(c[0],h(c[0]),'sk',ms=10) # 'sk'=cuadrito negro
plt.grid()

# %% [markdown]
# **Resultado:**
#
# Usando el criterio de la segunda derivada, no fue concluyente la evaluación del punto crítico, sin embargo, usando el criterio gráfico, obtuvimos un mínimo en $x=2$ para $h(x)=(x-2)^4$.
#
# ---

# %% [markdown]
# ## 3. Método para determinar extremos absolutos de una función continua y=f(x) en [a,b]
#
# - Determinar todos los valores críticos $c_1, c_2, c_3, \dots, c_n$ en $(a,b)$.
# - Evaluar $f$ en todos los valores críticos y en los extremos $x=a$ y $x=b$.
# - El más grande y el más pequeño de los valores de la lista $f(a), f(b), f(c_1), f(c_2), \dots, f(c_n)$ son el máximo absoluto y el mínimo absoluto, respectivamente, de $f$ en el intervalo $[a,b]$.

# %% [markdown]
# ### Ejemplo
#
# Determinar los extremos absolutos de $f(x)=x^2-2x+5$ en $\left[0,3\right]$.
#
# Obtenemos los puntos críticos de $f$ en $\left[0,3\right]$:

# %%
def f(x):
  return x**2-2*x+5

# %%
df=f(x).diff(x)
c=sym.solve(df)
c
# Out:
# [1]

# %% [markdown]
# Evaluamos $f$ en los extremos y en los puntos críticos:

# %%
x_num=np.array([0,1,3])
f(x_num)
# Out:
# array([5, 4, 8])

# %%
plt.plot(x_num,f(x_num),'o')
plt.plot(c[0],f(c[0]),'or',ms=10)
plt.grid()

# %% [markdown]
# **Resultado:**
#
# Como el punto crítico evaluado en la función $f(x)$ es el menor en el intervalo de interés, éste se trata de un mínimo.
#
# ---

# %% [markdown]
# ### Actividad
# Determinar los valores extremos absolutos de  $f(x) = (x-3)^2(x+3)^2$ en el intervalo $[1,\,4]$, usando `sympy`. Mostrar en una gráfica.

# %%
def f(x):
  return (x-3)**2*(x+3)**2
df=f(x).diff(x)
c=sym.solve(df)
c
# Out:
# [-3, 0, 3]

# %% [markdown]
# Como el intervalo de interés es de $[1,4]$, omitimos los primeros dos punto críticos.

# %%
x_num=np.array([1,3,4])
f(x_num)
# Out:
# array([64,  0, 49])

# %% [markdown]
# **Resultado:**
#
# Encontramo un mínimo en el punto $x=3$ dentro del intervalo $[1,4]$ para $f(x)=(x-3)^2(x+3)^2$.
#
# ---

# %% [markdown]
# ## Variable simbólica real
# Considere la siguiente función como criterio de optimización
# $$
# f(x)=(x^2+1)^2(x+1)^2
# $$
# encuentre los puntos críticos reales.

# %% [markdown]
# ```python
# # Usamos la variable simbólica previamente definida
# x
# ```

# %%
# Definimos una variable simbólica real
sym.var('x',real=True) # positive=True
# Out:
# x

# %%
def f(x):
  return (x**2+1)**2*(x+1)**2

# %%
df=f(x).diff(x)
c=sym.solve(df)
c
# Out:
# [-1]

# %%
# Gráfica
x_num=np.linspace(-3,1,100)
y_num=f(x_num)

plt.plot(x_num,y_num)
plt.plot(c[0],f(c[0]),'*',ms=10)
plt.grid()

# %% [markdown]
# ## Cambio de librerías
# Uso de funciones entre librerías `NumPy` y `SymPy`.
#
# Si tenemos la función
# $$
# f(x)=\mathrm{e}^{-x}\mathrm{cos}(2x),
# $$
#
# calcule los puntos críticos en el intervalo $[-1,1]$.

# %%
# Usamos 'x' simbólica real ;)
x
# Out:
# x

# %%
# Usando funciones de sympy
def f(x):
  return sym.exp(-x)*sym.cos(2*x)
df=f(x).diff(x)
c=sym.solve(df)
c
# Out:
# [-atan(1/2)/2]

# %%
float(c[0])
# Out:
# -0.23182380450040305

# %%
x_num=np.linspace(-1,1,100)
y_num=f(x_num) # Esto marca error

# %%
# Usando funciones de numpy
def f(x):
  return np.exp(-x)*np.cos(2*x)
df=f(x).diff(x) # Esto marca error. Equis de

# %%
# Ahora sí
f=sym.exp(-x)*sym.cos(2*x)
df=f.diff(x)
c=sym.solve(df)
c
# Out:
# [-atan(1/2)/2]

# %%
f_num=sym.lambdify(x,f,'numpy')
x_num=np.linspace(-1,1,100)
y_num=f_num(x_num) # Esto ya no marca error

plt.plot(x_num,y_num)
c_0=float(c[0])
plt.plot(c_0,f_num(c_0),'*',ms=10)
plt.grid()

# %% [markdown]
# ---
# 1. **Resistencia de una viga**  Una viga de madera tiene una sección transversal rectangular de altura $h$ y ancho $w$. La resistencia $S$ de la viga es directamente proporcional al ancho y al cuadrado de su altura ($S=kwh^2$, donde $k$ es una constante de proporcionalidad). ¿Cuáles son las dimensiones de la viga más fuerte que puede cortarse a partir de un leño redondo de $24$ pulgadas de diámetro?

# %%
#@markdown Código para visualizar el problema de **Resistencia de una viga**
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

C = patches.Circle((0, 0),12, fill=False,color='brown',lw=4)
S = patches.Rectangle((-9,-8),18,16,fill=False,color='k')
ax = plt.gca()
ax.add_artist(S)
ax.add_artist(C)

plt.text(0,8.5,'$w$')
plt.text(9.5,0,'$h$')

plt.plot([-9,9],[-8,8],'r--')
plt.text(0,2,'$24$')

plt.axis('equal')
plt.ylim([-15,15])
plt.axis('off')
plt.show()

# %% [markdown]
# **Solución:**
#
# Se desea maximazar la resistencia $S=kwh^2$, siendo $w$ el ancho de la viga y $h$ la altura.
#
# Se observa que, al modificar $w$ se modifica $h$ y viceversa a través de un triángulo rectángulo con hipotenusa de 24 pulgadas, es decir $24^2=w^2+h^2$. Sustituyendo $h$ en $S$, se tiene
# $$
# S(w)=kw(24^2-w^2),
# $$
# para $0<w<24$.

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
sym.var('w',positive=True)
def S(w):
  k=1500000               # 1015264 - 1740452 libra/pulgada^2
  return k*w*(24**2-w**2)

dS=S(w).diff(w)
c=sym.solve(dS)
c
# Out:
# [8*sqrt(3)]

# %%
x=np.linspace(0,24,100)
y=S(x)
plt.plot(x,y)
c_0=float(c[0])
plt.plot(c_0,S(c_0),'xr',ms=10)
plt.grid()

# %%
# Resistencia máxima
S(c[0]) # libras
# Out:
# 4608000000*sqrt(3)

# %%
# Cálculo de 'h'
float(24**2-c[0]**2)**0.5
# Out:
# 19.595917942265423

# %% [markdown]
# Obteniendo $h$:
#
# A partir del teorema de Pitágoras $24^2=h^2+w^2$ y sustituyendo el púnto óptimo de $w=8\sqrt{3}$, resulta
# \begin{eqnarray*}
# h&=&\sqrt{24^2-w^2}\\
# h&=&\sqrt{24^2-8\sqrt{3}}\\
# h&=&19.5959\;\mathrm{pulgadas}
# \end{eqnarray*}

# %% [markdown]
# ---
# 2. **Iluminación**  Una fuente luminosa se localiza sobre el centro de una mesa circular de $4 pies$ de diámetro. Encontrar la altura $h$ de la fuente luminosa de modo tal que la iluminación $I$ en el perímetro de la mesa sea máxima si $I=k(\sin \alpha)/s^2$, donde $s$ es la altura oblicua, $\alpha$ es el ángulo al cual la luz incide sobre la mesa y $k$ es una constante (El valor de esta última constante es irrelevante para el problema, ya que no se pide el valor de la iluminación).

# %%
#@markdown Código para visualizar el problema de **Iluminación**
E = patches.Ellipse((0, 0),10, 3,fc='white',ec='brown')
C = patches.Circle((0,10.5),0.5,color='y')
a = patches.Arc((-5,0),2,2,theta2=60)
p1 = patches.Rectangle((-5, -2),0.5, 2, fill=False,color='brown')
p2 = patches.Rectangle((4.5, -2),0.5, 2, fill=False,color='brown')
p3 = patches.Rectangle((-0.25, -3),0.5, 2, fill=False,color='brown')
ax = plt.gca()
ax.add_artist(p1)
ax.add_artist(p2)
ax.add_artist(p3)
ax.add_artist(E)
ax.add_artist(C)
ax.add_artist(a)

plt.text(2,5,'$s$')
plt.text(0,3,'$h$')
plt.text(-4,0.5,r'$\alpha$')
plt.text(-0.5,-1,'$4$ pies')

plt.plot([-5,0,5],[0,10,0],'y--')
plt.plot([-5,5],[0,0],'k--')
plt.plot([0,0],[0,10],'k--')


plt.axis('equal')
plt.ylim([-3.1,12])
plt.axis('off')
plt.show()

# %% [markdown]
# **Solución:**
#
# Se desea optimizar la iluminación $I=k/s^2\mathrm{sin}\alpha$, donde $\mathrm{sin}\alpha=\frac{h}{s}$ y $s^2=h^2+2^2$. Sustituyendo $h$ en $S$, se tiene:
# $$
# I(h)=k\dfrac{h/\sqrt{h^2+2^2}}{h^2+2^2}=\dfrac{kh}{(h^2+2^2)^{3/2}},
# $$
# para $h$ real positiva (por simplicidad, definimos $k=1$).

# %%
sym.var('h',real=True,positive=True)
def I(h):
  k=1
  return k*h/(h**2+4)**(3/2)
I(h)
# Out:
# h/(h**2 + 4)**1.5

# %%
dI=I(h).diff(h)
c=sym.solve(dI)
c
# Out:
# [1.41421356237310]

# %%
# Iluminación
I(c[0])
# Out:
# 0.0962250448649376

# %%
x=np.linspace(0,3,100)
y=I(x)
plt.plot(x,y)
plt.plot(c[0],I(c[0]),'ok',ms=10)
plt.grid()

# %% [markdown]
# La iluminación máxima es $I=0.0962$ y se consigue a una altura $h=1.4142$ pies.

# %% [markdown]
# 3. **Fuerza mínima**  Se diseña un componente para deslizar un bloque de acero con peso $W=10 N$ a través de una mesa y sobre una canaleta. Se opone al movimiento del bloque una fuerza de fricción proporcional a su peso aparente (sea $k=0.1$ la constante de proporcionalidad). Determinar la fuerza mínima $f$ necesaria para deslizar el bloque y encontrar el valor correspondiente de $\theta$.
#
# Ayudín: $f\cos \theta$ es la fuerza de dirección del movimiento, y $f\sin\theta$ es la fuerza que tiende a levantar el bloque. De tal modo, el peso aparente del bloque es $W-f\sin\theta$.

# %%
#@markdown Código del diagrama de **Fuerza mínima**
W = patches.Rectangle((0, 2),0.8, 0.5, fill=False,color='k')
a = patches.Arrow(0.8,2.25,1,0.5,width=0.1,color='k')
arc = patches.Arc((0.8,2.25),1,1,theta2=30)
ax = plt.gca()
ax.add_artist(W)
ax.add_artist(a)
ax.add_artist(arc)

plt.text(0.2,2.6,'$W$')
plt.text(1.8,3,'$f$')
plt.text(1.35,2.305,r'$\theta$')

plt.plot([1.8,2.8],[2.75,3.25],'k')
plt.plot([0.8,2],[2.25,2.25],'k--')
plt.plot([-1,-1,2,2],[0,2,2,0],'k')


plt.axis('equal')
plt.ylim([0,4])
plt.axis('off')
plt.show()

# %% [markdown]
# Se desea minimizar la fuerza $f$ para que el bloque se empiece a mover, es decir la fuerza mínima tal que la componente horizontal de $f$ es igual a la fricción:
# $$
# fr=f\cos\theta,
# $$
# donde $fr=k(W-f\sin\theta)$.
#
# Notamos que al variar el ángulo $\theta$, la fricción se modifica, por lo que la función de fuerza en términos del ángulo es
# $$
# f(\theta)=\dfrac{kW}{\cos\theta+k\sin\theta},
# $$
# para $0\leq\theta<\pi/2$.

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
sym.var('theta')
k=0.1
W=10
f=k*W/(sym.cos(theta)+k*sym.sin(theta))
f
# Out:
# 1.0/(0.1*sin(theta) + cos(theta))

# %%
df=f.diff(theta)
c=sym.solve(df)
c
# Out:
# [0.0996686524911620]

# %%
x=np.linspace(0,0.5,100)
f_num=sym.lambdify(theta,f,'numpy')
y=f_num(x)

plt.plot(x,y)
c_0=float(c[0])
plt.plot(c_0,f_num(c_0),'*r',ms=10)
plt.grid()

# %%
# Fuerza mínima
f_num(c_0)     # Newtons
# Out:
# 0.9950371902099893

# %% [markdown]
# **Respuesta:**
#
# El ángulo óptimo para que el bloque se mueva con una fuerza mínima de $f=0.9950$ N, es de $\theta=0.09967$ rad.

# %% [markdown]
# ### En varias variables...
#
# El procedimiento es análogo.
#
# Si una función $f:\mathbb{R}^n\to\mathbb{R}$ alcanza un máximo o mínimo local en $\boldsymbol{x}=\boldsymbol{c}\in\mathbb{R}^n$, y $f$ es diferenciable en el punto $\boldsymbol{x}=\boldsymbol{c}$, entonces $\left.\frac{\partial f}{\partial \boldsymbol{x}}\right|_{\boldsymbol{x}=\boldsymbol{c}}=\boldsymbol{0}$ (todas las derivadas parciales en el punto $\boldsymbol{x}=\boldsymbol{c}$ son cero).
#
# **Criterio de la segunda derivada:** para ver si es máximo o mínimo, se toma la segunda derivada (matriz Hessiana) y se verifica definición negativa o positiva, respectivamente.
#
# Si se restringe a cierta región, hay ciertas técnicas. La más general, pero también la más compleja es la de **multiplicadores de Lagrange**.

# %% [markdown]
# **Ejemplo:** Determinar los valores extremo de $z(x,y)= (x-3)^2 + (y+5)^2$ usando el criterio de la segunda derivada y corroborarlo con la gráfica.

# %%
sym.var('x')
sym.var('y')
def z(x,y):
  return (x-3)**2+(y+5)**2
z(x,y)
# Out:
# (x - 3)**2 + (y + 5)**2

# %%
zdx=z(x,y).diff(x)
zdy=z(x,y).diff(y)
zdx,zdy
# Out:
# (2*x - 6, 2*y + 10)

# %%
c=sym.solve([zdx,zdy],[x,y])
c
# Out:
# {x: 3, y: -5}

# %%
c[x],c[y]
# Out:
# (3, -5)

# %%
zdxx=zdx.diff(x)
zdxy=zdx.diff(y) # zdy.diff(x)
zdyy=zdy.diff(y)
H=sym.Matrix([[zdxx,zdxy],
              [zdxy,zdyy]])
H                              # Los elementos de la diagonal principal son positivos
# Out:
# Matrix([
# [2, 0],
# [0, 2]])

# %%
H.det()                        # El determinante también es positivo. 'H'>0
# Out:
# 4
